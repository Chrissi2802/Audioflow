# %% [markdown]
# # Audioflow

# %%
import sys

sys.path.append("..")

import audioflow

# %%
audioflow.display_banner()
# Out:
#     _             _ _        __ _
#    / \  _   _  __| (_) ___  / _| | _____      __
#   / _ \| | | |/ _` | |/ _ \| |_| |/ _ \ \ /\ / /
#  / ___ \ |_| | (_| | | (_) |  _| | (_) \ V  V /
# /_/   \_\__,_|\__,_|_|\___/|_| |_|\___/ \_/\_/
#
#
# Audioflow
# Version: 0.1.0
# Author:  Chrissi

# %%
url = "https://www.youtube.com/watch?v=2LpPSeONeG4&list=RD2LpPSeONeG4"
AudioDownloader = audioflow.core.downloader.AudioDownloader()

# %%
AudioDownloader.validate_url(url)
# Out:
# True

# %%
AudioDownloader.extract_info(url)
# Out:
# AudioMetaData(title='Mix - Andi schiebt Anders X Johnny Cap - Kleiner Pimmel, großer Bauch (Official Lyric Video)', artist=None, album=None, duration=None, url='https://www.youtube.com/watch?v=2LpPSeONeG4&list=RD2LpPSeONeG4', thumbnail_url=None, source_id='RD2LpPSeONeG4')

# %%
AudioDownloader.download(url)
# Out:
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# WARNING: [youtube] 2LpPSeONeG4: Some web_safari client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# WARNING: [youtube] 2LpPSeONeG4: Some web client https formats have been skipped as they are missing a url. YouTube is forcing SABR streaming for this client. See  https://github.com/yt-dlp/yt-dlp/issues/12482  for more details
# ERROR: Postprocessing: ffprobe and ffmpeg not found. Please install or provide the path using --ffmpeg-location
# ...
